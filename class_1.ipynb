# %% [markdown]
# # FSDI 114 - Data Structure and Algorithms
#
# ## Class 1
#
# This is an example of a text (paragraph from html)

# %%
for char in "Hello World":
    print(char)

# Press shift + (enter)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
print("hellow world")
x = 10
print(x-5)
# Out:
# hellow world
# 5

# %%
print (x+10)
# Out:
# 20

# %% [markdown]
# ## Python Recap
#
# - List
# - Variables
# - Expressions
# - Functions

# %%
# Variables
my_name = 'Sergio'
age = 46
is_active = True
print(f"My name is {my_name}")
# Out:
# My name is Sergio

# %%
# Collections (lists, dictionaries, tuples, sets)
my_list = ["things to do", "study", "practice favorit hobby"]
diff = ["stirng", 10, True, 'c']
my_dictionary = {
    "name": "Sergio",
    "age": 46,
    "is_active": True
}
print(my_list[0])
print(my_dictionary["name"])
# Out:
# things to do
# Sergio

# %%
# Expressions - Operators
a = 10
b = 3

# Arithmetics
print(a + b)
print(a - b)
print(a * b)
print(a / b)

# Relational
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)

# Logical (and, or, not)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# True
# False
# True
# False
# False

# %%
# Functions
def my_function():
    a = 10
    b = 3
    print(a + b)

def my_function_with_parameters(a,b):
    print(a + b)

def my_function_with_return():
    a = 10
    b = 3
    return a+b

my_function()
my_function_with_parameters(10,3)
result = my_function_with_return()
print(result)
# Out:
# 13
# 13
# 13

# %% [markdown]
# START
# - Get all the ingredients you will need
# - Get all the materials you will need
# - Get two slices of your favorite loaf of bread and place on a plate.
# - Apply your favorite sauce (mayonaise, mustard, BBQ sauce, etc.)
# - Slice lettuce, tomatoe, onion, and pickle
# - Place your sliced ingredients on either slice of bread (or both slices)
# - Place your favorite sliced meat on either slice of bread
# - Place a slice of your favorite cheese on either slice of bread.
# - Sprinkle any salt, pepper, or other favorite seasoning on either slice of bread.
# - Close your slices and wrap in wax paper or towel sheet.
# - Serve place at table with a glass of favorite beverage.
# - Note: You may also want to cut your sandwich diagonally to make it easier to eat your sandwich.
# END

# %% [markdown]
# Pseudocode:
# Create a list of numbers
# Interate through the list with a for-loop and compare the numbers.
# Order the numbers in ascending order
# Find the largest number
# Print the last number in the list.

# %%
nums = [2, 4, 6, 10, 3.7]
new_nums = []
for integer in nums:
    new_num= integer % 2
    if new_num == 0:
        new_nums.append(new_num)
        print(new_nums)
        print(len(new_nums))


def get_total_even_integers():
    nums2 = [3, 5, 27, 20, 6, 3.5, 60]
    even_int_count = []
    for integer in nums2:
        new_num = integer % 2
        if new_num == 0:
            even_int_count.append(new_num)
            
    return (f"There are {len(even_int_count)} even numbers in this list.")
        
get_total_even_integers()
# Out:
# [0]
# 1
# [0, 0]
# 2
# [0, 0, 0]
# 3
# [0, 0, 0, 0]
# 4
# 'There are 3 even numbers in this list.'

# %%
nums = [12, 4, 27, 3, 1000, 50, 7]
nums.sort()
print(nums)
last_num = nums[len(nums) - 1]
print(last_num)

def get_largest_num():
    nums = [12, 4, 27, 3, 1000, 50, 7]
    nums.sort()
    print(nums)
    last_num = nums[len(nums) - 1]
    return last_num

def get_largest_num():
    nums = ["1", "2"]
    nums.sort()
    print(nums)
    last_num = nums[len(nums) - 1]
    return last_num

nums = [12, 4, 27, 3, 1000, 50, 7]
for integer in nums:
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)

nums = [7, 6, 5, 4, 3, 2, 1]
for integer in nums:
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)

nums = [1, 2, 3, 4, 5, 6, 7]
for integer in nums:
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)
       if nums[0] > nums[1]:
              current_index = 0
              target_index = 1
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[0])
              print(nums[1])
       elif nums[1] > nums[2]:
              current_index = 1
              target_index = 2
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[1])
              print(nums[2])
       elif nums[2] > nums[3]:
              current_index = 2
              target_index = 3
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[2])
              print(nums[3])
       elif nums[3] > nums[4]:
              current_index = 3
              target_index = 4
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[3])
              print(nums[4])
       elif nums[4] > nums[5]:
              current_index = 4
              target_index = 5
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[4])
              print(nums[5])
       elif nums[5] > nums[6]:
              current_index = 5
              target_index = 6
              item = nums.pop(current_index)
              nums.insert(target_index, item)
              print(nums[5])
              print(nums[6])
       print(nums)

def order_integers():
       nums = [1000, 50, 27, 12, 7, 4, 3]
       for item in nums:
              if nums[0] > nums[1]:
                     current_index = 0
                     target_index = 1
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[0])
                     print(nums[1])
              elif nums[1] > nums[2]:
                     current_index = 1
                     target_index = 2
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[1])
                     print(nums[2])
              elif nums[2] > nums[3]:
                     current_index = 2
                     target_index = 3
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[2])
                     print(nums[3])
              elif nums[3] > nums[4]:
                     current_index = 3
                     target_index = 4
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[3])
                     print(nums[4])
              elif nums[4] > nums[5]:
                     current_index = 4
                     target_index = 5
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[4])
                     print(nums[5])
              elif nums[5] > nums[6]:
                     current_index = 5
                     target_index = 6
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[5])
                     print(nums[6])
              print(nums)
              if nums[0] > nums[1]:
                     current_index = 0
                     target_index = 1
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[0])
                     print(nums[1])
              elif nums[1] > nums[2]:
                     current_index = 1
                     target_index = 2
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[1])
                     print(nums[2])
              elif nums[2] > nums[3]:
                     current_index = 2
                     target_index = 3
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[2])
                     print(nums[3])
              elif nums[3] > nums[4]:
                     current_index = 3
                     target_index = 4
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[3])
                     print(nums[4])
              elif nums[4] > nums[5]:
                     current_index = 4
                     target_index = 5
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[4])
                     print(nums[5])
              elif nums[5] > nums[6]:
                     current_index = 5
                     target_index = 6
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[5])
                     print(nums[6])
              print(nums)
              if nums[0] > nums[1]:
                     current_index = 0
                     target_index = 1
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[0])
                     print(nums[1])
              elif nums[1] > nums[2]:
                     current_index = 1
                     target_index = 2
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[1])
                     print(nums[2])
              elif nums[2] > nums[3]:
                     current_index = 2
                     target_index = 3
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[2])
                     print(nums[3])
              elif nums[3] > nums[4]:
                     current_index = 3
                     target_index = 4
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[3])
                     print(nums[4])
              elif nums[4] > nums[5]:
                     current_index = 4
                     target_index = 5
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[4])
                     print(nums[5])
              elif nums[5] > nums[6]:
                     current_index = 5
                     target_index = 6
                     item = nums.pop(current_index)
                     nums.insert(target_index, item)
                     print(nums[5])
                     print(nums[6])
                     return nums
              print(nums)
                                  
result= order_integers()
# Out:
# [3, 4, 7, 12, 27, 50, 1000]
# 1000
# 4
# 12
# [4, 12, 27, 3, 1000, 50, 7]
# 3
# 27
# [4, 12, 3, 27, 1000, 50, 7]
# 3
# 12
# [4, 3, 12, 27, 1000, 50, 7]
# 3
# 4
# [3, 4, 12, 27, 1000, 50, 7]
# 50
# 1000
# [3, 4, 12, 27, 50, 1000, 7]
# 7
# 1000
# [3, 4, 12, 27, 50, 7, 1000]
# 7
# 50
# [3, 4, 12, 27, 7, 50, 1000]
# 7
# 27
# [3, 4, 12, 7, 27, 50, 1000]
# 7
# 12
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# [3, 4, 7, 12, 27, 50, 1000]
# 6
# 7
# [6, 7, 5, 4, 3, 2, 1]
# 5
# 7
# [6, 5, 7, 4, 3, 2, 1]
# 5
# 6
# [5, 6, 7, 4, 3, 2, 1]
# 4
# 7
# [5, 6, 4, 7, 3, 2, 1]
# 4
# 6
# [5, 4, 6, 7, 3, 2, 1]
# 4
# 5
# [4, 5, 6, 7, 3, 2, 1]
# 3
# 7
# [4, 5, 6, 3, 7, 2, 1]
# 3
# 6
# ...
